# %%
# importing the Twitter library
import tweepy
# importing the NLP(Natural Language Processing) library
from textblob import TextBlob

# %%
# Setting the credentials to twitter API:
# Register on twitter to get your own Key:
consumer_key = 'X'
consumer_key_secret = 'Y'

access_token = 'X'
access_token_secret = 'Y'

# %%
# Authorising the API to acces the credentials and the Platform:
auth = tweepy.OAuthHandler(consumer_key, consumer_key_secret)

auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit = True)

# %% [markdown]
#
# A) Polarity = Defines the positivity or negativity of the text;
#
# B) Subjectivity: Defines the text on the basis that how much of it is an opinion vs how factual it is.

# %%
public_tweets = api.search('BlackLifeMatters', count=20)
i=0
for tweet in public_tweets:
    i+=1
    print(i)
    
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    
    if analysis.sentiment[0] > 0:
        print('-> Positive\n\n')
    elif analysis.sentiment[0] < 0:
        print('-> Negative\n\n')
    else:
        print('-> Neutral\n\n')
# Out:
# 1
# #BlacklivesStillMatter
# #blacklifematters
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 2
# @256Solomon @Noble30879886 Well done, Solomon💪 🌎🌏🌍👍
#
# #FaceTheClimateEmergenscy
# #SaveAllTheRainforests… https://t.co/P3h5OvFhdJ
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 3
# Tennisstar @NaomiOsaka protestiert gegen #Rassismus und #Polizeigewalt an. #blacklifematters
#
# Osaka spielt nicht m… https://t.co/PfpxgH0HIS
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 4
# "Nous ne tuons que les Noirs." : le dérapage d'un policier américain https://t.co/Q4VbnnUsmD via @YouTube… https://t.co/dv1sTvlCHl
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 5
# RT @YansIID: #blacklifematters #BlackLivesMatter #JusticePourAdama ✏️ 🎨 https://t.co/KHoG2kUaRp
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 6
# Endlich reagiert die Aufmerksamkeits wichtige Abteilung richtig #nba #MLS #WNBA #MLB nur die #NHL wieder in ihrer e… https://t.co/ljutpjTaaF
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 7
# Voilà l'autopsie de George Floyd. @lemondefr @Le_Figaro @LEXPRESS @Mediapart @libe vous nous préparez un article là… https://t.co/L7Ub1my1RN
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 8
# @realDonaldTrump But Mr President you waited patiently for too long to act against police brutality,oh thanks to#Bl… https://t.co/dU6jw3fnhH
# Sentiment(polarity=0.07500000000000001, subjectivity=0.30000000000000004)
# -> Positive
#
#
# 9
# @WakioDorcas @mulindwa_guy @vanessa_vash @lizwathuti @KaoHua3 Amazing Dorcas 🌎🌏🌍👍
#
# #FaceTheClimateEmergenscy… https://t.co/k5CnTsosRs
# Sentiment(polarity=0.6000000000000001, subjectivity=0.9)
# -> Positive
#
#
# 10
# Le boycott historique du sport américain après les tirs policiers sur Jacob Blake: “On en a marre”… https://t.co/omcVNNWe4d
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 11
# @WhoopiGoldberg the #BlackLifeMatters movement is installed to lead us away from what is happening with the global… https://t.co/gs2aJvPGe8
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 12
# @gonorrhoeaa Blacklifematters
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 13
# @DwyaneWade @NBA all entities benefiting from minority communities need to pool resources &amp; lobby for change-NBA, N… https://t.co/yG9wcTfsvu
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 14
# @ChrisBHaynes all entities benefiting from minority communities need to pool resources &amp; lobby for change-NBA, NFL,… https://t.co/n8qKnsMo8r
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 15
# @washingtonpost all entities benefiting from minority communities need to pool resources &amp; lobby for change-NBA, NF… https://t.co/C6O5f7NMry
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 16
# @jemelehill Handle, all entities benefiting from minority communities need to pool resources &amp; lobby for change-NBA… https://t.co/APgYUrURAP
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 17
# @stephenasmith Stephen, all entities benefiting from minority communities need to pool resources &amp; lobby for change… https://t.co/2cVY2X6nN8
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 18
# #blacklifematters https://t.co/3ROi7uLpBy
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 19
# @ESPNBooger Booger, all entities benefiting from minority communities need to pool resources &amp; lobby for change-NBA… https://t.co/iW83XY4BQ7
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 20
# RT @Anja_Piel: Rassismus tötet. Es muss sich was ändern. #blacklifematters  Die Schwester von  Jacob Blake mit einem machtvollen Statement…
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral

# %%
public_tweets = api.search('Covid-19', count=20)
i=0
for tweet in public_tweets:
    i+=1
    print(i)
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    if analysis.sentiment[0] > 0:
        print('-> Positive\n\n')
    elif analysis.sentiment[0] < 0:
        print('-> Negative\n\n')
    else:
        print('-> Neutral\n\n')
# Out:
# 1
# RT @C2riIzUjSjnxhUX: 絶対5類にしてはだめ。もっと国で責任持たないと。SARSは1類です。covid-19 ウイルス名SARS-CoV-2はSARSの親戚みたいなそっくりさん。病床確保できないからと投げるな！もっと努力しろ！と言いたい。何故ドイツで3日で出来…
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 2
# RT @isonmayu: ESTA ES LA ORDEN DEL RÉGIMEN: "PACIENTES CON COVID DEJÉNLOS MORIR"
# EN VENEZUELA NO HAY RESPIRADORES ARTIFICIALES.
# #26Ago #27A…
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 3
# RT @JaiveerShergill: Fed up with the taunting over non-deposit of  ₹15 Lac in every account, BJP Govt has deposited double the amount + int…
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 4
# RT @Zac_Petkanas: BREAKING: Florida confirmed 9K new COVID-19 cases among children within 15 days as schools reopen https://t.co/9X0uVqLtpa
# Sentiment(polarity=0.2681818181818182, subjectivity=0.7272727272727273)
# -> Positive
#
#
# 5
# RT @C2riIzUjSjnxhUX: 絶対5類にしてはだめ。もっと国で責任持たないと。SARSは1類です。covid-19 ウイルス名SARS-CoV-2はSARSの親戚みたいなそっくりさん。病床確保できないからと投げるな！もっと努力しろ！と言いたい。何故ドイツで3日で出来…
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 6
# RT @IMPriyankJazzz: #AntiStudentNarendraModi
#
# Kon sahi kon galat ?
#
# Kya exams lena zarura hai iss situation me ... Covid-19 fir lockdown f…
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 7
# RT @NastyBobUSA: @Rkon7713 @LivNow @GovNedLamont @NickRicci5 Big Trouble for the Dem “pandemic” narrative now. 👀 https://t.co/32gCvZqzGq
# Sentiment(polarity=-0.1, subjectivity=0.15000000000000002)
# -> Negative
#
#
# 8
# RT @IMPriyankJazzz: #AntiStudentNarendraModi
#
# Kon sahi kon galat ?
#
# Kya exams lena zarura hai iss situation me ... Covid-19 fir lockdown f…
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 9
# RT @the_hindu: #TamilNadu Chief Minister Edappadi K. Palaniswami said he had written to Prime Minister Modi in July for the postponement of…
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 10
# 'Alarming and frightening': Scale of COVID-19 spread among Victorian healthcare workers revealed https://t.co/pWgZ5nxI9r #covid19
# Sentiment(polarity=-0.3, subjectivity=0.8)
# -> Negative
#
#
# 11
# RT @AskAnshul: I tweeted for postponing exams due to Covid-19 cases, not for politics.
#
# AIMIM and Congress want postponement of exams too,…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# -> Negative
#
#
# 12
# RT @lizwathuti: Covid-19 is not the only issue. Floods have also ravaged the states of Bihar &amp; Assam, affecting millions of people. Conduct…
# Sentiment(polarity=0.0, subjectivity=1.0)
# -> Neutral
#
#
# 13
# RT @swilkinsonbc: Steve Coogan, Christy Moore, Massive Attack, Peter Gabriel, Lankum, Frances Black &amp; over 240 others call for a military e…
# Sentiment(polarity=-0.08888888888888889, subjectivity=0.5111111111111112)
# -> Negative
#
#
# 14
# RT @cchukudebelu: Covid-19 is probably the major reason why there hasn't been a mass shooting in a church, school or movie theater yet in t…
# Sentiment(polarity=0.0625, subjectivity=0.5)
# -> Positive
#
#
# 15
# RT @AskAnshul: I tweeted for postponing exams due to Covid-19 cases, not for politics.
#
# AIMIM and Congress want postponement of exams too,…
# Sentiment(polarity=-0.125, subjectivity=0.375)
# -> Negative
#
#
# 16
# RT @soutikBBC: Four members of the Greater Andamanese tribe have tested positive for Covid-19.
# The Greater Andamanese are believed to have…
# Sentiment(polarity=0.4090909090909091, subjectivity=0.5151515151515151)
# -> Positive
#
#
# 17
# RT @IOL: Thato Abraham is alleged to have played a vital behind-the-scenes role between Blue Label Telecoms, the SA Postbank and a former S…
# Sentiment(polarity=0.0, subjectivity=0.15)
# -> Neutral
#
#
# 18
# RT @KairosNeige: Raoult, le dealer d huile de serpent dont la science a bloqué le port de Marseille #GiletsJaunes
#
# https://t.co/N4ptD0PDBC
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 19
# RT @vatansevda60: ACİL!! Trabzon Kanuni Eğitim ve Araştırma Hastanesi'nde Covid-19 nedeniyle yatmakta olan Yusuf Ziya Hacıbayramoğlu adlı h…
# Sentiment(polarity=0.0, subjectivity=0.0)
# -> Neutral
#
#
# 20
# Pemkot Kendari Bangun Covid-19 Center dari DID https://t.co/UAW2Np8WYZ
# Sentiment(polarity=-0.1, subjectivity=0.1)
# -> Negative
